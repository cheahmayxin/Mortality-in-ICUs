# %% [markdown]
# # ADS1002 Project Report Notebook Template
#
# ## 1. Title, Members & Theme
#
# Provide the project title, list members of the group and overall theme or context. Include dataset source and domain.

# %% [markdown]
# ## 2. Introduction & Research Questions
#
# Introduce the problem, motivation, and objectives. Clearly list the research questions or hypotheses.

# %% [markdown]
# ## 3. Data Dictionary
#
# List each feature/column, its type, and meaning. Helpful for readers unfamiliar with the dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

ICU = pd.read_csv("Preprocessed ICU data.csv")
ICU.head()
# Out:
#    RecordID  Age  Gender      Height  ICUType2  ICUType3  ICUType4  \
# 0    132543   68     1.0  180.300000         0         1         0
# 1    132545   88     0.0  169.787227         0         1         0
# 2    132547   64     1.0  180.300000         0         0         0
# 3    132551   78     0.0  162.600000         0         1         0
# 4    132554   64     0.0  169.787227         0         1         0
#
#    Mean_Weight.x  Mean_GCS.x   Mean_HR.x  ...   Max_ALT.y   Max_AST.y  \
# 0      84.600000   14.888889   72.971429  ...   12.000000   15.000000
# 1      83.054136   15.000000   79.520000  ...  189.169186  260.323666
# 2     114.000000    8.333333   81.318182  ...   60.000000  162.000000
# 3      48.400000   13.250000   78.125000  ...   46.000000   82.000000
# 4      60.700000   15.000000  129.363636  ...  189.169186  260.323666
#
#    Max_Bilirubin.y  Max_Lactate.y  Max_Cholesterol.y  Max_TroponinI.y  \
# 0         0.200000       2.395461         156.842105         7.132683
# 1         1.979557       2.395461         156.842105         7.132683
# 2         0.400000       2.395461         212.000000         1.300000
# 3         0.300000       2.300000         156.842105         3.500000
# 4         1.979557       2.395461         156.842105         7.132683
#
#    Max_TroponinT.y  SAPS.I  SOFA  In.hospital_death
# 0         1.114629       7     1                  0
# 1         1.114629      17     2                  0
# 2         1.114629      14    11                  0
# 3         1.114629      19     8                  1
# 4         1.114629      11     0                  0
#
# [5 rows x 232 columns]

# %%
ICU.shape
# Out:
# (1474, 232)

# %%
ICU.isna().sum()
# Out:
# RecordID             0
# Age                  0
# Gender               0
# Height               0
# ICUType2             0
#                     ..
# Max_TroponinI.y      0
# Max_TroponinT.y      0
# SAPS.I               0
# SOFA                 0
# In.hospital_death    0
# Length: 232, dtype: int64

# %%
ICU.describe
# Out:
# <bound method NDFrame.describe of       RecordID  Age  Gender      Height  ICUType2  ICUType3  ICUType4  \
# 0       132543   68     1.0  180.300000         0         1         0
# 1       132545   88     0.0  169.787227         0         1         0
# 2       132547   64     1.0  180.300000         0         0         0
# 3       132551   78     0.0  162.600000         0         1         0
# 4       132554   64     0.0  169.787227         0         1         0
# ...        ...  ...     ...         ...       ...       ...       ...
# 1469    142661   89     1.0  177.800000         0         0         1
# 1470    142662   86     1.0  162.600000         0         1         0
# 1471    142664   51     0.0  169.787227         0         0         1
# 1472    142665   70     0.0  169.787227         0         0         1
# 1473    142671   37     1.0  169.787227         0         1         0
#
#       Mean_Weight.x  Mean_GCS.x   Mean_HR.x  ...    Max_ALT.y    Max_AST.y  \
# 0         84.600000   14.888889   72.971429  ...    12.000000    15.000000
# 1         83.054136   15.000000   79.520000  ...   189.169186   260.323666
# 2        114.000000    8.333333   81.318182  ...    60.000000   162.000000
# 3         48.400000   13.250000   78.125000  ...    46.000000    82.000000
# 4         60.700000   15.000000  129.363636  ...   189.169186   260.323666
# ...             ...         ...         ...  ...          ...          ...
# 1469      64.000000   11.214286   86.260870  ...   189.169186   260.323666
# 1470      53.000000   13.000000   85.517241  ...    28.000000    35.000000
# 1471      75.000000    9.909091   91.147059  ...   189.169186   260.323666
# 1472      87.000000   10.833333  101.083333  ...   189.169186   260.323666
# 1473      87.400000    6.400000   91.785714  ...  1513.000000  1277.000000
#
#       Max_Bilirubin.y  Max_Lactate.y  Max_Cholesterol.y  Max_TroponinI.y  \
# 0            0.200000       2.395461         156.842105         7.132683
# 1            1.979557       2.395461         156.842105         7.132683
# 2            0.400000       2.395461         212.000000         1.300000
# 3            0.300000       2.300000         156.842105         3.500000
# 4            1.979557       2.395461         156.842105         7.132683
# ...               ...            ...                ...              ...
# 1469         1.979557       2.395461         156.842105         7.132683
# 1470         0.900000       2.395461         156.842105         7.132683
# 1471         1.979557       2.395461         156.842105         7.132683
# 1472         1.979557       1.100000         156.842105         7.132683
# 1473         0.600000       1.900000         156.842105         7.132683
#
#       Max_TroponinT.y  SAPS.I  SOFA  In.hospital_death
# 0            1.114629       7     1                  0
# 1            1.114629      17     2                  0
# 2            1.114629      14    11                  0
# 3            1.114629      19     8                  1
# 4            1.114629      11     0                  0
# ...               ...     ...   ...                ...
# 1469         1.114629       6     4                  0
# 1470         1.114629      19     8                  0
# 1471         1.114629      13     8                  0
# 1472         1.114629      19     7                  0
# 1473         1.114629      22    10                  1
#
# [1474 rows x 232 columns]>

# %% [markdown]
# ## 4. Executive Summary
#
# Summarise key findings, major insights, and conclusions. Usually written after analysis is complete.

# %% [markdown]
# ## 5. Data Loading
#
# Describe the dataset(s), including size, format, and initial observations. Mention file paths or sources.

# %% [markdown]
# ## 6. Data Cleaning
#
# Explain how missing values, duplicates, and errors are handled. Include reasoning for any deletions, imputations, or corrections.

# %% [markdown]
# ## 7. Preprocessing
#
# Describe encoding of categorical variables, scaling or normalization of numerical features, and any other preparations for analysis or modeling.

# %% [markdown]
# ## 8. Feature Engineering
#
# Document any new variables created to enhance model performance or analysis, with reasoning.

# %% [markdown]
# ## 9. Preliminary Analysis / Exploratory Data Analysis (EDA)
#
# Visualise distributions, correlations, and patterns in the data. Identify relationships and trends relevant to your research questions.

# %% [markdown]
# ## 10. Conclusions from EDA
#
# Summarise the insights gained from EDA and how they guide further analysis or modeling.

# %% [markdown]
# ## 11. Modeling / Analysis
#
# Outline the predictive models or statistical analyses applied. Explain why each method was chosen and any evaluation strategy.

# %% [markdown]
# ## 12. Model / Analysis Conclusions
#
# Summarise model performance, key metrics, and interpretation. Discuss limitations or potential improvements.

# %% [markdown]
# ## 13. Overall Conclusions
#
# Answer your research questions based on findings. Summarise key insights, implications, and possible next steps.

# %% [markdown]
# ## 14. Limitations
#
# Document assumptions made during the project and any known limitations of the data, methodology, or analysis.

# %% [markdown]
# ## 15. References
#
# List sources, datasets, and literature cited in your report.

# %% [markdown]
# ## Optional: Appendix
